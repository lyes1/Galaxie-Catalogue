# %% [markdown]
# # Catalogues exploration
# Ce notebook a pour but d'analyser et de rassembler les diffrentes sources de données afin de constituer un catalogue qui se veut être assez exhaustif accessible via une Web API.

# %% [markdown]
# ## 1. OpenNGC catalogue
#  Ce catalogue a été télécharger depuis [ce lien](https://github.com/mattiaverga/OpenNGC). Il contient toutes les données présentes dans le catalogue NGC.

# %%
#import sys
import os
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 500)
CHEMIN_SOURCES = os.path.join("..","1_Data_brute")

# %%
# Lecture de données depuis le fichier source vers un objet DataFrame
col_names = ['NGC_IC_designation', 
    'object_type',
    'Right_Ascension',
    'Declinaison',
    'Constelation_name_abrv',
    'major_axis',
    'minor_axis',
    'major__axis_position_angle', 
    'B_Apparent_Magnitude',
    'V_Apparent_Magnitude',             
    'J_Apparent_Magnitude',
    'H_Apparent_Magnitude',
    'K_Apparent_Magnitude',
    'Mean_surface_brigthness', 
    'Hubble_morphological_type',
    'center_star_U_maghitude',
    'center_star_B_maghitude',
    'center_star_V_maghitude',
    'Messier_number',
    'NGC_numner',
    'IC_number',
    'Center_star_name',
    'Identifiers',
    'Common_names',       
    'NED_notes',  
    'OpenNGC_notes']

NGC_mattiaAverga_GitHub = pd.read_csv(os.path.join(CHEMIN_SOURCES, "NGC_mattiaAverga_GitHub.csv"), sep=';',header=0, names=col_names)
NGC_mattiaAverga_GitHub.shape
# Out:
# (13958, 26)

# %% [markdown]
# Dans cette [source](http://messier.obspm.fr/m-q&a.html), on peut lire:
# - M24: the Milky Way Patch in Sagittarius; it contains however the 11th magnitude cluster NGC 6603 which is sometimes erroneously listed as M24. Also, it may be that IC 4715 is M24.
# - M25: this is IC 4725,
# - M40: the double star Winnecke 4
# - M45: the Pleiades; however, this cluster is associated with nebulae which have NGC numbers.

# %%
NGC_mattiaAverga_GitHub.loc[(NGC_mattiaAverga_GitHub['NGC_IC_designation']=='IC4725') |
                        (NGC_mattiaAverga_GitHub['NGC_IC_designation']=='IC4715')]
# Out:
#      NGC_IC_designation object_type Right_Ascension  Declinaison  \
# 4923             IC4715        *Ass     18:16:56.12  -18:30:52.4
# 4933             IC4725         OCl     18:31:46.77  -19:06:53.8
#
#      Constelation_name_abrv  major_axis  minor_axis  \
# 4923                    Sgr       120.0        60.0
# 4933                    Sgr        14.1         NaN
#
#       major__axis_position_angle  B_Apparent_Magnitude  V_Apparent_Magnitude  \
# 4923                         NaN                   NaN                   4.5
# 4933                         NaN                  5.29                   4.6
#
#       J_Apparent_Magnitude  H_Apparent_Magnitude  K_Apparent_Magnitude  \
# 4923                   NaN                   NaN                   NaN
# 4933                   NaN                   NaN                   NaN
#
#       Mean_surface_brigthness Hubble_morphological_type  \
# 4923                      NaN                       NaN
# 4933                      NaN                       NaN
#
#       center_star_U_maghitude  center_star_B_maghitude  \
# 4923                      NaN                      NaN
# 4933                      NaN                      NaN
#
#       center_star_V_maghitude  Messier_number NGC_numner IC_number  \
# 4923                      NaN            24.0        NaN       NaN
# 4933                      NaN            25.0        NaN       NaN
#
#      Center_star_name Identifiers          Common_names  \
# 4923              NaN         NaN  Small Sgr Star Cloud
# 4933              NaN         NaN                   NaN
#
#                   NED_notes                             OpenNGC_notes
# 4923  Milky Way star cloud.  V-mag taken from HEASARC's messier table
# 4933                    NaN                                       NaN

# %% [markdown]
# *Note:* Les objets M24 et  M25 existent dans NGC_mattiaAverga_GitHub. Mais M40 et M45 n'y sont pas. Ils sont dans l'Addendum.

# %% [markdown]
# ### Addendum
# Le fichier Addendum contient des objets qui ne font partie des catalogue NGC ou IC mais qui peuvent interessé les amateurs de l'astronomie. Les objets M40 et M45 du catalogue de Messier n'ont pas d'identifiant NGC donc ils sont présents dans cet addendum (voir [source](https://github.com/mattiaverga/OpenNGC/blob/master/README.md)).

# %%
# Lecture de données depuis le fichier source vers un objet DataFrame
addendum_NGC_mattiaAverga_GitHub = pd.read_csv(os.path.join(CHEMIN_SOURCES, "addendum_NGC_mattiaAverga_GitHub.csv"), sep=';', header=0, names=col_names)
addendum_NGC_mattiaAverga_GitHub.shape
# Out:
# (20, 26)

# %% [markdown]
# ## 2. Construction du catalogue de Messier
# Dans ce qui suit, nous allons construire notre catalogue de Messier à partir de plusieurs sources.

# %% [markdown]
# ### 2.1. Le catalogue de Messier: *'Datastro'*
# [Source](https://www.datastro.eu/explore/dataset/catalogue-de-messier/table/?disjunctive.objet&disjunctive.mag&disjunctive.english_name_nom_en_anglais&disjunctive.french_name_nom_francais&disjunctive.latin_name_nom_latin&sort=messier)

# %% [markdown]
# #### 2.1.1. Lecture du fichier

# %%
# Lecture de données depuis le fichier source vers un objet DataFrame
col_names = ['Messier_number',
    'NGC_IC_designation', 
    'object_type',
    'Season',
    'Magnitude',
    'Constellation_EN',
    'Constellation_FR',
    'Constellation_Latin',
    'Right_Ascension',        
    'Declinaison',
    'Distance_light_year',
    'Size',
    'Discoverer',
    'Year',
    'Image1',
    'Image2',
    'Constelation_abr' ]
messier_Datastro_website = pd.read_csv(os.path.join(CHEMIN_SOURCES, "messier_Datastro_website.csv"), sep=';', header=0, names=col_names)
messier_Datastro_website.shape
# Out:
# (110, 17)

# %%
# Corrections d'un identifiant NGC 
messier_Datastro_website.loc[messier_Datastro_website['NGC_IC_designation']=='NGC 9176', 'NGC_IC_designation'] = 'NGC 1976'

# %% [markdown]
# #### 2.1.2. Division du catalogue de Messier

# %% [markdown]
# Nous avons besoin de traiter à part les deux objets M40 et M45. Car ces deux objets vont être mergés avec les données présentes dans le *Addendum* et le reste des objets Messier vont être mergés avec les données du *NGC_mattiaAverga_GitHub*.

# %%
messier_Datastro_website_without_M40_M45 = messier_Datastro_website[(messier_Datastro_website['Messier_number']!='M40') &
                        (messier_Datastro_website['Messier_number']!='M45')].copy()

messier_Datastro_website_M40_M45 = messier_Datastro_website[(messier_Datastro_website['Messier_number']=='M40') |
                        (messier_Datastro_website['Messier_number']=='M45')].copy()

# %% [markdown]
# #### 2.1.3. Merging entre Messier et NGC

# %%
# Normalisation du NGC_designation: NGCnnnn (suppression des vides)
messier_Datastro_website_without_M40_M45.loc[messier_Datastro_website_without_M40_M45['NGC_IC_designation'].str.len()==8
                             , 'NGC_IC_designation']= messier_Datastro_website_without_M40_M45['NGC_IC_designation'].str.replace(" ", "")

messier_Datastro_website_without_M40_M45.loc[messier_Datastro_website_without_M40_M45['NGC_IC_designation'].str.len()==7
                             , 'NGC_IC_designation']= messier_Datastro_website_without_M40_M45['NGC_IC_designation'].str.replace(" ", "0")

# %%
# Merge du dataframe qui contient tout les objets sauf M40 et M45
merge_messier_Datastro_website_without_M40_M45 = messier_Datastro_website_without_M40_M45.merge(NGC_mattiaAverga_GitHub, how='left', on='NGC_IC_designation')
merge_messier_Datastro_website_without_M40_M45.shape
# Out:
# (108, 42)

# %% [markdown]
# *Liste des features:*
#
# - Messier_number_x
# - NGC_IC_designation
# - *object_type_x* (delete object_type_y is abreviation)
# - Season
# - Magnitude
# - Constellation_EN
# - Constellation_FR
# - Constellation_Latin
# - Right_Ascension_x  1 Nan(keep Right_Ascension_y no nan)
# - Declinaison_x  1 Nan(keep Declinaison_y no nan)
# - Distance_light_year
# - Size
# - Discoverer
# - Year
# - Image1
# - Image2
# - *Constelation_abr (Delete)*
# - *object_type_y  (delete)*
# - *Right_Ascension_y*
# - *Declinaison_y*
# - Constelation_name_abrv
# - major_axis
# - minor_axis
# - major__axis_position_angle
# - B_Apparent_Magnitude
# - V_Apparent_Magnitude
# - J_Apparent_Magnitude
# - H_Apparent_Magnitude
# - K_Apparent_Magnitude
# - Mean_surface_brigthness
# - Hubble_morphological_type
# - center_star_U_maghitude
# - center_star_B_maghitude
# - center_star_V_maghitude
# - *Messier_number_y (delete)*
# - NGC_numner  (6 double-listed in NGC)
# - *IC_number (delete: 108 Nan)*
# - Center_star_name
# - Identifiers
# - Common_names
# - NED_notes
# - OpenNGC_notes

# %%
# Suppression des colunne inutiles ou redondantes
drop_list = ['object_type_y', 'Right_Ascension_x', 'Declinaison_x', 'Messier_number_y', 'IC_number']
rename_lis = {'Messier_number_x' : 'Messier_number',
             'object_type_x' : 'object_type',
             'Right_Ascension_y' : 'Right_Ascension',
             'Declinaison_y' : 'Declinaison'}

merge_messier_Datastro_website_without_M40_M45 = merge_messier_Datastro_website_without_M40_M45.drop(columns=drop_list)
merge_messier_Datastro_website_without_M40_M45 = merge_messier_Datastro_website_without_M40_M45.rename(columns=rename_lis)
merge_messier_Datastro_website_without_M40_M45.shape
# Out:
# (108, 37)

# %%
# Extraction des objets M40 et M45 depuis l'Addendum
Open_NGC_M40_M45 = addendum_NGC_mattiaAverga_GitHub[~addendum_NGC_mattiaAverga_GitHub['Messier_number'].isna()].copy()
# Ajout du Numero Messier standardisé
Open_NGC_M40_M45['Messier_number_bis'] = 'M'+Open_NGC_M40_M45['Messier_number'].astype('int').astype('str')

# Remplacement de la colonne Messier_number par la nouvelle colonne
Open_NGC_M40_M45 = Open_NGC_M40_M45.drop(columns='Messier_number')
Open_NGC_M40_M45 = Open_NGC_M40_M45.rename(columns={'Messier_number_bis': 'Messier_number'})
Open_NGC_M40_M45
# Out:
#    NGC_IC_designation object_type Right_Ascension Declinaison  \
# 13               M040          **      12:22:16.1   +58:05:04
# 14             Mel022         OCl      03:47:28.6   +24:06:19
#
#    Constelation_name_abrv  major_axis  minor_axis  major__axis_position_angle  \
# 13                    UMa         NaN         NaN                         NaN
# 14                    Tau       150.0       150.0                        90.0
#
#     B_Apparent_Magnitude  V_Apparent_Magnitude  J_Apparent_Magnitude  \
# 13                   NaN                   8.0                   NaN
# 14                   NaN                   1.2                   NaN
#
#     H_Apparent_Magnitude  K_Apparent_Magnitude  Mean_surface_brigthness  \
# 13                   NaN                   NaN                      NaN
# 14                   NaN                   NaN                      NaN
#
#    Hubble_morphological_type  center_star_U_maghitude  \
# 13                       NaN                      NaN
# 14                       NaN                      NaN
#
#     center_star_B_maghitude  center_star_V_maghitude  NGC_numner  IC_number  \
# 13                      NaN                      NaN         NaN        NaN
# 14                      NaN                      NaN         NaN        NaN
#
#     Center_star_name        Identifiers Common_names NED_notes  \
# 13               NaN  WDS J12222+5805AB          NaN       NaN
# 14               NaN          MWSC 0305     Pleiades       NaN
#
#                                         OpenNGC_notes Messier_number
# 13            VMag taken from HEASARC's messier table            M40
# 14  Coordinates taken from Simbad, VMag taken from...            M45

# %%
# Merge du dataframe qui contient M40 et M45
merge_messier_Datastro_website_M40_M45 = messier_Datastro_website_M40_M45.merge(Open_NGC_M40_M45, how='left', on='Messier_number')
merge_messier_Datastro_website_M40_M45
# Out:
#   Messier_number NGC_IC_designation_x                object_type_x  \
# 0            M45                  NaN   Open Cluster / Amas Ouvert
# 1            M40           Winnecke 4  Double star / Étoile Double
#
#                Season  Magnitude Constellation_EN Constellation_FR  \
# 0      Winter / Hiver          1              NaN              NaN
# 1  Spring / Printemps          9              NaN              NaN
#
#   Constellation_Latin Right_Ascension_x Declinaison_x  Distance_light_year  \
# 0                 NaN               NaN           NaN                410.0
# 1                 NaN               NaN           NaN                  NaN
#
#      Size Discoverer    Year                                Image1  \
# 0  120,0'        NaN     NaN  http://www.lasam.ca/messier/M045.JPG
# 1     NaN   Hevelius  1660.0  http://www.lasam.ca/messier/M040.JPG
#
#                                               Image2 Constelation_abr  \
# 0  https://www.datastro.eu/api/v2/catalog/dataset...              NaN
# 1  https://www.datastro.eu/api/v2/catalog/dataset...              NaN
#
#   NGC_IC_designation_y object_type_y Right_Ascension_y Declinaison_y  \
# 0               Mel022           OCl        03:47:28.6     +24:06:19
# 1                 M040            **        12:22:16.1     +58:05:04
#
#   Constelation_name_abrv  major_axis  minor_axis  major__axis_position_angle  \
# 0                    Tau       150.0       150.0                        90.0
# 1                    UMa         NaN         NaN                         NaN
#
#    B_Apparent_Magnitude  V_Apparent_Magnitude  J_Apparent_Magnitude  \
# 0                   NaN                   1.2                   NaN
# 1                   NaN                   8.0                   NaN
#
#    H_Apparent_Magnitude  K_Apparent_Magnitude  Mean_surface_brigthness  \
# 0                   NaN                   NaN                      NaN
# 1                   NaN                   NaN                      NaN
#
#   Hubble_morphological_type  center_star_U_maghitude  center_star_B_maghitude  \
# 0                       NaN                      NaN                      NaN
# 1                       NaN                      NaN                      NaN
#
#    center_star_V_maghitude  NGC_numner  IC_number  Center_star_name  \
# 0                      NaN         NaN        NaN               NaN
# 1                      NaN         NaN        NaN               NaN
#
#          Identifiers Common_names NED_notes  \
# 0          MWSC 0305     Pleiades       NaN
# 1  WDS J12222+5805AB          NaN       NaN
#
#                                        OpenNGC_notes
# 0  Coordinates taken from Simbad, VMag taken from...
# 1            VMag taken from HEASARC's messier table

# %%
# Move data before deleting NGC_IC_designation_y
merge_messier_Datastro_website_M40_M45.loc[merge_messier_Datastro_website_M40_M45['NGC_IC_designation_x'].isna(),
                                          'NGC_IC_designation_x'] = merge_messier_Datastro_website_M40_M45['NGC_IC_designation_y']

# %%
# Suppression des colunne inutiles ou redondantes
drop_list = ['NGC_IC_designation_y', 'object_type_y', 'Right_Ascension_x', 'Declinaison_x', 'IC_number']
rename_lis = {'NGC_IC_designation_x': 'NGC_IC_designation',
             'object_type_x' : 'object_type',
             'Right_Ascension_y' : 'Right_Ascension',
             'Declinaison_y' : 'Declinaison'}

merge_messier_Datastro_website_M40_M45 = merge_messier_Datastro_website_M40_M45.drop(columns=drop_list)
merge_messier_Datastro_website_M40_M45 = merge_messier_Datastro_website_M40_M45.rename(columns=rename_lis)
merge_messier_Datastro_website_M40_M45.shape
# Out:
# (2, 37)

# %% [markdown]
# #### 2.1.4. Concatination entre Messier contenant les objets M40 et M45 et le Messier ayant le reste des objets

# %%
messier_catalogue = pd.concat([merge_messier_Datastro_website_without_M40_M45, merge_messier_Datastro_website_M40_M45])

# %%
messier_catalogue[messier_catalogue['Hubble_morphological_type'].isna()]
# Out:
#     Messier_number NGC_IC_designation  \
# 2              M76            NGC0650
# 3              M80            NGC6093
# 4              M93            NGC2447
# 7              M37            NGC2099
# 8              M36            NGC1960
# 9              M48            NGC2548
# 14             M16            NGC6611
# 15              M4            NGC6121
# 16             M15            NGC7078
# 17             M18            NGC6613
# 18             M21            NGC6531
# 19             M35            NGC2168
# 21             M73            NGC6994
# 23             M78            NGC2068
# 26             M69            NGC6637
# 27             M57            NGC6720
# 29             M44            NGC2632
# 31             M72            NGC6981
# 32              M3            NGC5272
# 33              M7            NGC6475
# 34              M5            NGC5904
# 35             M39            NGC7092
# 36             M29            NGC6913
# 37            M107            NGC6171
# 39             M34            NGC1039
# 40             M56            NGC6779
# 43              M9            NGC6333
# 44              M1            NGC1952
# 45             M22            NGC6656
# 46             M30            NGC7099
# ..             ...                ...
# 60             M68            NGC4590
# 63             M47            NGC2422
# 65             M79            NGC1904
# 67             M20            NGC6514
# 68             M10            NGC6254
# 69             M14            NGC6402
# 70             M24            NGC6603
# 73             M75            NGC6864
# 75             M41            NGC2287
# 76             M46            NGC2437
# 80              M8            NGC6523
# 81             M11            NGC6705
# 82             M23            NGC6494
# 83             M25             IC4725
# 84             M54            NGC6715
# 85             M62            NGC6266
# 87             M67            NGC2682
# 88             M71            NGC6838
# 91            M103            NGC0581
# 93             M70            NGC6681
# 94             M50            NGC2323
# 97             M97            NGC3587
# 99             M92            NGC6341
# 100            M90            NGC4560
# 102             M2            NGC7089
# 104            M17            NGC6618
# 105            M27            NGC6853
# 106            M28            NGC6626
# 0              M45             Mel022
# 1              M40         Winnecke 4
# 91                  Open Cluster / Amas Ouvert    Autumn / Automne          7
# 93          Globular Cluster / Amas Globulaire        Summer / Été          8
# 94                  Open Cluster / Amas Ouvert      Winter / Hiver          5
# 97     Planetary Nebula / Nébuleuse Planétaire  Spring / Printemps         11
# 99          Globular Cluster / Amas Globulaire        Summer / Été          6
# 100                           Galaxy / Galaxie  Spring / Printemps          9
# 102         Globular Cluster / Amas Globulaire    Autumn / Automne          6
# 104     Emission Nebula / Nébuleuse à émission        Summer / Été          6
# 105    Planetary Nebula / Nébuleuse Planétaire        Summer / Été          8
# 106         Globular Cluster / Amas Globulaire        Summer / Été          6
# 0                   Open Cluster / Amas Ouvert      Winter / Hiver          1
# 1                  Double star / Étoile Double  Spring / Printemps          9
#
#      Constellation_EN      Constellation_FR Constellation_Latin  \
# 2             Perseus                Persée             Perseus
# 3            Scorpion              Scorpion            Scorpius
# 4     Stern,Poop deck                 Poupe              Puppis
# 7          Charioteer                Cocher              Auriga
# 8          Charioteer                Cocher              Auriga
# 9    Hydra, Sea Snake                 Hydre               Hydra
# 14                NaN                   NaN                 NaN
# 15           Scorpion              Scorpion            Scorpius
# 16       Winged Horse                Pégase             Pegasus
# 17             Archer            Sagittaire         Sagittarius
# 18             Archer            Sagittaire         Sagittarius
# 19              Twins           Les Gémeaux              Gemini
# 21       Water Bearer               Verseau            Aquarius
# 23      Orion, Hunter                 Orion               Orion
# 26             Archer            Sagittaire         Sagittarius
# 27               Lyre                  Lyre                Lyra
# 29               Crab                Cancer              Cancer
# 31       Water Bearer               Verseau            Aquarius
# 32         Hound Dogs  Les Chiens de chasse      Canes Venatici
# 33           Scorpion              Scorpion            Scorpius
# 34                NaN                   NaN                 NaN
# 35               Swan                 Cygne              Cygnus
# 36               Swan                 Cygne              Cygnus
# 37     Serpent Holder             Ophiuchus           Ophiuchus
# 39            Perseus                Persée             Perseus
# 40               Lyre                  Lyre                Lyra
# 43     Serpent Holder             Ophiuchus           Ophiuchus
# 44               Bull               Taureau              Taurus
# 45             Archer            Sagittaire         Sagittarius
# 46               Goat            Capricorne         Capricornus
# ..                ...                   ...                 ...
# 60   Hydra, Sea Snake                 Hydre               Hydra
# 63    Stern,Poop deck                 Poupe              Puppis
# 65               Hare                Lièvre               Lepus
# 67             Archer            Sagittaire         Sagittarius
# 68     Serpent Holder             Ophiuchus           Ophiuchus
# 69     Serpent Holder             Ophiuchus           Ophiuchus
# 70             Archer            Sagittaire         Sagittarius
# 73             Archer            Sagittaire         Sagittarius
# 75          Great Dog           Grand Chien         Canis Major
# 76    Stern,Poop deck                 Poupe              Puppis
# 80             Archer            Sagittaire         Sagittarius
# 81             Shield     L’Écu de Sobieski              Scutum
# 82             Archer            Sagittaire         Sagittarius
# 83             Archer            Sagittaire         Sagittarius
# 84             Archer            Sagittaire         Sagittarius
# 85     Serpent Holder             Ophiuchus           Ophiuchus
# 87               Crab                Cancer              Cancer
# 88              Arrow                Flèche             Sagitta
# 91         Cassiopeia             Cassiopée          Cassiopeia
# 93             Archer            Sagittaire         Sagittarius
# 102  http://www.lasam.ca/messier/M002.JPG
# 104  http://www.lasam.ca/messier/M017.JPG
# 105  http://www.lasam.ca/messier/M027.JPG
# 106  http://www.lasam.ca/messier/M028.JPG
# 0    http://www.lasam.ca/messier/M045.JPG
# 1    http://www.lasam.ca/messier/M040.JPG
#
#                                                 Image2 Constelation_abr  \
# 2    https://www.datastro.eu/api/v2/catalog/dataset...              Per
# 3    https://www.datastro.eu/api/v2/catalog/dataset...              Sco
# 4    https://www.datastro.eu/api/v2/catalog/dataset...              Pup
# 7    https://www.datastro.eu/api/v2/catalog/dataset...              Aur
# 8    https://www.datastro.eu/api/v2/catalog/dataset...              Aur
# 9    https://www.datastro.eu/api/v2/catalog/dataset...              Hya
# 14   https://www.datastro.eu/api/v2/catalog/dataset...              Se2
# 15   https://www.datastro.eu/api/v2/catalog/dataset...              Sco
# 16   https://www.datastro.eu/api/v2/catalog/dataset...              Peg
# 17   https://www.datastro.eu/api/v2/catalog/dataset...              Sgr
# 18   https://www.datastro.eu/api/v2/catalog/dataset...              Sgr
# 19   https://www.datastro.eu/api/v2/catalog/dataset...              Gem
# 21   https://www.datastro.eu/api/v2/catalog/dataset...              Aqr
# 23   https://www.datastro.eu/api/v2/catalog/dataset...              Ori
# 26   https://www.datastro.eu/api/v2/catalog/dataset...              Sgr
# 27   https://www.datastro.eu/api/v2/catalog/dataset...              Lyr
# 29   https://www.datastro.eu/api/v2/catalog/dataset...              Cnc
# 31   https://www.datastro.eu/api/v2/catalog/dataset...              Aqr
# 32   https://www.datastro.eu/api/v2/catalog/dataset...              CVn
# 33   https://www.datastro.eu/api/v2/catalog/dataset...              Sco
# 34   https://www.datastro.eu/api/v2/catalog/dataset...              Se1
# 35   https://www.datastro.eu/api/v2/catalog/dataset...              Cyg
# 36   https://www.datastro.eu/api/v2/catalog/dataset...              Cyg
# 37   https://www.datastro.eu/api/v2/catalog/dataset...              Oph
# 39   https://www.datastro.eu/api/v2/catalog/dataset...              Per
# 40   https://www.datastro.eu/api/v2/catalog/dataset...              Lyr
# 43   https://www.datastro.eu/api/v2/catalog/dataset...              Oph
# 44   https://www.datastro.eu/api/v2/catalog/dataset...              Tau
# 45   https://www.datastro.eu/api/v2/catalog/dataset...              Sgr
# 46   https://www.datastro.eu/api/v2/catalog/dataset...              Cap
# ..                                                 ...              ...
# 60   https://www.datastro.eu/api/v2/catalog/dataset...              Hya
# 63   https://www.datastro.eu/api/v2/catalog/dataset...              Pup
# 65   https://www.datastro.eu/api/v2/catalog/dataset...              Lep
# 67   https://www.datastro.eu/api/v2/catalog/dataset...              Sgr
# 68   https://www.datastro.eu/api/v2/catalog/dataset...              Oph
# 69   https://www.datastro.eu/api/v2/catalog/dataset...              Oph
# 70   https://www.datastro.eu/api/v2/catalog/dataset...              Sgr
# 73   https://www.datastro.eu/api/v2/catalog/dataset...              Sgr
# 75   https://www.datastro.eu/api/v2/catalog/dataset...              CMa
# 76   https://www.datastro.eu/api/v2/catalog/dataset...              Pup
# 80   https://www.datastro.eu/api/v2/catalog/dataset...              Sgr
# 81   https://www.datastro.eu/api/v2/catalog/dataset...              Sct
# 82   https://www.datastro.eu/api/v2/catalog/dataset...              Sgr
# 83   https://www.datastro.eu/api/v2/catalog/dataset...              Sgr
# 84   https://www.datastro.eu/api/v2/catalog/dataset...              Sgr
# 85   https://www.datastro.eu/api/v2/catalog/dataset...              Oph
# 87   https://www.datastro.eu/api/v2/catalog/dataset...              Cnc
# 88   https://www.datastro.eu/api/v2/catalog/dataset...              Sge
# 91   https://www.datastro.eu/api/v2/catalog/dataset...              Cas
# 93   https://www.datastro.eu/api/v2/catalog/dataset...              Sgr
# 94   https://www.datastro.eu/api/v2/catalog/dataset...              Mon
# 97   https://www.datastro.eu/api/v2/catalog/dataset...              UMa
# 99   https://www.datastro.eu/api/v2/catalog/dataset...              Her
# 100  https://www.datastro.eu/api/v2/catalog/dataset...              Vir
# 102  https://www.datastro.eu/api/v2/catalog/dataset...              Aqr
# 104  https://www.datastro.eu/api/v2/catalog/dataset...              Sgr
# 105  https://www.datastro.eu/api/v2/catalog/dataset...              Vul
# 106  https://www.datastro.eu/api/v2/catalog/dataset...              Sgr
# 0    https://www.datastro.eu/api/v2/catalog/dataset...              NaN
# 1    https://www.datastro.eu/api/v2/catalog/dataset...              NaN
#
#     Right_Ascension  Declinaison Constelation_name_abrv  major_axis  \
# 2       01:42:19.69  +51:34:31.7                    Per        1.12
# 3       16:17:02.51  -22:58:30.4                    Sco        5.70
# 4       07:44:29.23  -23:51:11.1                    Pup       15.00
# 7       05:52:18.35  +32:33:10.8                    Aur       11.40
# 8       05:36:17.74  +34:08:26.7                    Aur        7.20
# 9       08:13:43.18  -05:45:01.6                    Hya       28.20
# 14      18:18:48.17  -13:48:26.0                    Se2      120.00
# 15      16:23:35.40  -26:31:31.9                    Sco       28.20
# 16      21:29:58.38  +12:10:00.6                    Peg       11.10
# 17      18:19:58.49  -17:06:07.1                    Sgr        6.00
# 18      18:04:13.45  -22:29:24.2                    Sgr        6.00
# 19      06:09:05.06  +24:20:19.1                    Gem       24.00
# 21      20:58:55.97  -12:38:07.8                    Aqr         NaN
# 23      05:46:45.82  +00:04:45.5                    Ori        4.50
# 26      18:31:23.23  -32:20:52.7                    Sgr        5.70
# 27      18:53:35.01  +33:01:42.9                    Lyr        1.27
# 29      08:40:22.20  +19:40:19.4                    Cnc      108.60
# 31      20:53:27.91  -12:32:13.4                    Aqr        4.50
# 32      13:42:11.23  +28:22:31.6                    CVn       16.20
# 33      17:53:51.18  -34:47:34.2                    Sco       22.20
# 34      15:18:33.75  +02:04:57.7                    Se1       15.00
# 35      21:31:48.32  +48:26:17.4                    Cyg       19.50
# 36      20:23:57.77  +38:30:27.6                    Cyg        3.60
# 37      16:32:31.92  -13:03:13.1                    Oph        7.80
# 39      02:42:07.40  +42:44:46.1                    Per       22.50
# 40      19:16:35.51  +30:11:04.2                    Lyr        5.80
# 43      17:19:11.78  -18:30:58.5                    Oph        6.90
# 44      05:34:31.97  +22:00:52.1                    Tau        8.00
# 45      18:36:24.20  -23:54:12.3                    Sgr       12.60
# 46      21:40:22.02  -23:10:44.7                    Cap        9.00
# ..              ...          ...                    ...         ...
# 60      12:39:28.01  -26:44:34.9                    Hya        6.60
# 63      07:36:35.02  -14:28:57.4                    Pup       19.80
# 65      05:24:10.59  -24:31:27.2                    Lep        7.20
# 67      18:02:42.11  -22:58:18.8                    Sgr       28.00
# 68      16:57:08.99  -04:05:57.6                    Oph        9.30
# 69      17:37:36.16  -03:14:45.3                    Oph         NaN
# 70      18:18:26.97  -18:24:21.8                    Sgr        4.20
# 73      20:06:04.84  -21:55:20.0                    Sgr        3.60
# 75      06:45:59.94  -20:45:15.2                    CMa       12.00
# 76      07:41:46.82  -14:48:36.0                    Pup       21.00
# 80      18:03:41.27  -24:22:48.6                    Sgr       45.00
# 99          NaN                         NaN                   NaN
# 100         NaN                         NaN                   NaN
# 102         NaN                         NaN                   NaN
# 104         NaN                         NaN                  6.00
# 105         NaN                         NaN                  7.60
# 106         NaN                         NaN                   NaN
# 0         150.0                        90.0                   NaN
# 1           NaN                         NaN                   NaN
#
#      V_Apparent_Magnitude  J_Apparent_Magnitude  H_Apparent_Magnitude  \
# 2                   10.10                   NaN                   NaN
# 3                    7.30                   NaN                   NaN
# 4                    6.20                   NaN                   NaN
# 7                    5.60                   NaN                   NaN
# 8                    6.00                   NaN                   NaN
# 9                    5.80                   NaN                   NaN
# 14                   6.00                   NaN                   NaN
# 15                   5.40                   NaN                   NaN
# 16                   6.30                   NaN                   NaN
# 17                   6.90                   NaN                   NaN
# 18                   5.90                   NaN                   NaN
# 19                   5.10                   NaN                   NaN
# 21                   8.90                   NaN                   NaN
# 23                   8.00                   NaN                   NaN
# 26                   8.31                   NaN                   NaN
# 27                   8.80                 16.40                   NaN
# 29                   3.10                   NaN                   NaN
# 31                   8.96                   NaN                   NaN
# 32                   6.39                   NaN                   NaN
# 33                   3.30                   NaN                   NaN
# 34                   5.95                   NaN                   NaN
# 35                   4.60                   NaN                   NaN
# 36                   6.60                   NaN                   NaN
# 37                   8.85                   NaN                   NaN
# 39                   5.20                   NaN                   NaN
# 40                   8.40                   NaN                   NaN
# 43                   8.42                   NaN                   NaN
# 44                   8.40                   NaN                   NaN
# 45                   6.17                   NaN                   NaN
# 46                   7.10                   NaN                   NaN
# ..                    ...                   ...                   ...
# 60                   7.96                   NaN                   NaN
# 63                   4.40                   NaN                   NaN
# 65                   8.16                   NaN                   NaN
# 67                   8.50                   NaN                   NaN
# 68                   4.98                   NaN                   NaN
# 69                   5.73                   NaN                   NaN
# 70                  11.10                   NaN                   NaN
# 73                   8.26                  6.93                  6.43
# 75                   4.50                   NaN                   NaN
# 76                   6.10                   NaN                   NaN
# 80                   5.80                   NaN                   NaN
# 81                   5.80                   NaN                   NaN
# 82                   5.50                   NaN                   NaN
# 83                   4.60                   NaN                   NaN
# 84                   7.70                   NaN                   NaN
# 85                   7.39                   NaN                   NaN
# 87                   6.90                   NaN                   NaN
# 88                   6.10                   NaN                   NaN
# 91                   7.40                   NaN                   NaN
# 93                   9.06                   NaN                   NaN
# 94                   5.90                   NaN                   NaN
# 97                   9.90                 16.71                   NaN
# 99                   6.52                   NaN                   NaN
# 100                   NaN                   NaN                   NaN
# 102                  6.25                   NaN                   NaN
# 104                  7.00                   NaN                   NaN
# 105                  7.40                 11.79                 10.61
# 106                  6.90                   NaN                   NaN
# 0                    1.20                   NaN                   NaN
# 1                    8.00                   NaN                   NaN
#
#      K_Apparent_Magnitude  Mean_surface_brigthness Hubble_morphological_type  \
# 2                     NaN                      NaN                       NaN
# 3                     NaN                      NaN                       NaN
# 4                     NaN
# 83                       NaN                      NaN
# 84                       NaN                      NaN
# 85                       NaN                      NaN
# 87                       NaN                      NaN
# 88                       NaN                      NaN
# 91                       NaN                      NaN
# 93                       NaN                      NaN
# 94                       NaN                      NaN
# 97                     14.36                    15.66
# 99                       NaN                      NaN
# 100                      NaN                      NaN
# 102                      NaN                      NaN
# 104                      NaN                      NaN
# 105                    12.43                    13.66
# 106                      NaN                      NaN
# 0                        NaN                      NaN
# 1                        NaN                      NaN
#
#      center_star_V_maghitude NGC_numner Center_star_name  \
# 2                      17.48       0651              NaN
# 3                        NaN        NaN              NaN
# 4                        NaN        NaN              NaN
# 7                        NaN        NaN              NaN
# 8                        NaN        NaN              NaN
# 9                        NaN        NaN              NaN
# 14                       NaN        NaN              NaN
# 15                       NaN        NaN              NaN
# 16                       NaN        NaN              NaN
# 17                       NaN        NaN              NaN
# 18                       NaN        NaN              NaN
# 19                       NaN        NaN              NaN
# 21                       NaN        NaN              NaN
# 23                       NaN        NaN              NaN
# 26                       NaN       6634              NaN
# 27                     15.29        NaN        HD 175353
# 29                       NaN        NaN              NaN
# 31                       NaN        NaN              NaN
# 32                       NaN        NaN              NaN
# 33                       NaN        NaN              NaN
# 34                       NaN        NaN              NaN
# 35                       NaN        NaN              NaN
# 36                       NaN        NaN              NaN
# 37                       NaN        NaN              NaN
# 39                       NaN        NaN              NaN
# 40                       NaN        NaN              NaN
# 43                       NaN        NaN              NaN
# 44                       NaN        NaN              NaN
# 45                       NaN        NaN              NaN
# 46                       NaN        NaN              NaN
# ..                       ...        ...              ...
# 60                       NaN        NaN              NaN
# 63                       NaN       2478              NaN
# 65                       NaN        NaN              NaN
# 67                       NaN        NaN              NaN
# 68                       NaN        NaN              NaN
# 69                       NaN        NaN              NaN
# 70                       NaN        NaN              NaN
# 73                       NaN        NaN              NaN
# 75                       NaN        NaN              NaN
# 76                       NaN        NaN              NaN
# 80                       NaN       6533              NaN
# 81                       NaN        NaN              NaN
# 82                       NaN        NaN              NaN
# 83                       NaN        NaN              NaN
# 84                       NaN        NaN              NaN
# 85                       NaN        NaN              NaN
# 87                       NaN        NaN              NaN
# 88                       NaN       6839              NaN
# 91                       NaN        NaN              NaN
# 93                       NaN        NaN              NaN
# 94                       NaN        NaN              NaN
# 97                     16.01        NaN              NaN
# 99                       NaN        NaN              NaN
# 100                      NaN       4526              NaN
# 102                      NaN        NaN              NaN
# 104                      NaN        NaN              NaN
# 105                    13.94        NaN       BD+22 3878
# 106                      NaN        NaN              NaN
# 0                        NaN        NaN              NaN
# 1                        NaN        NaN              NaN
#
#                                            Identifiers  \
# 2    2MASX J01421808+5134243,IRAS 01391+5119,PN G13...
# 3                                            MWSC 2376
# 4                                            MWSC 1324
# 7                                            MWSC 0689
# 8                                            MWSC 0594
# 9                                            MWSC 1454
# 14                                    LBN 67,MWSC 2886
# 15                                           MWSC 2396
# 16            IRAS 21274+1156,MWSC 3518,PN G065.0-27.3
# 17                                           MWSC 2892
# 18                                           MWSC 2796
# 19                                           MWSC 0754
# 21                                                 NaN
# 23                                           MWSC 0664
# 26                                           MWSC 2936
# 27                      IRAS 18517+3257,PN G063.1+13.9
# 29                                           MWSC 1527
# 31                                           MWSC 3419
# 32                                           MWSC 2152
# 33                                           MWSC 2739
# 34                                           MWSC 2286
# 35                                           MWSC 3521
# 36                                           MWSC 3329
# 37                                           MWSC 2422
# 39                                           MWSC 0223
# 40                                           MWSC 3077
# 43                                           MWSC 2567
# 44                             IRAS 05315+2158,LBN 833
# 45                                           MWSC 2961
# 46                                           MWSC 3543
# ..                                                 ...
# 60                                           MWSC 2059
# 63                                           MWSC 1278
# 65                                           MWSC 0528
# 67                                    LBN 27,MWSC 2789
# 68                                           MWSC 2498
# 69                                           MWSC 2643
# 70                               ESO 590-017,MWSC 2883
# 73                   2MASX J20060484-2155201,MWSC 3254
# 75                                           MWSC 0978
# 76                                           MWSC 1313
# 80                                              LBN 25
# 81                                           MWSC 3008
# 82                                           MWSC 2757
# 83                                                 NaN
# 84                                           MWSC 3023
# 85                                           MWSC 2512
# 87                                           MWSC 1585
# 88                                           MWSC 3200
# 91                                           MWSC 0124
# 93                                           MWSC 2981
# 94                                           MWSC 1072
# 97   IRAS 11119+5517,PN G148.4+57.0,SDSS J111447.71...
# 99                                           MWSC 2557
# 100                                                NaN
# 102                                          MWSC 3526
# 104                                   LBN 60,MWSC 2896
# 105             2MASX J19593637+2243157,PN G060.8-03.6
# 106                                          MWSC 2908
# 0                                            MWSC 0305
# 1                                    WDS J12222+5805AB
#
#                                           Common_names  \
# 2    Barbell Nebula,Cork Nebula,Little Dumbbell Nebula
# 3                                                  NaN
# 4                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 14                                        Eagle Nebula
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 21                                                 NaN
# 23                                                 NaN
# 26                                                 NaN
# 27                                         Ring Nebula
# 29                            Beehive,Praesepe Cluster
# 31                                                 NaN
# 32                                                 NaN
# 33                                   Ptolemy's Cluster
# 34                                                 NaN
# 35                                                 NaN
# 36                                                 NaN
# 37                                                 NaN
# 39                                                 NaN
# 40                                                 NaN
# 43                                                 NaN
# 44                                                 NaN
# 45                                                 NaN
# 46                                                 NaN
# ..                                                 ...
# 60                                                 NaN
# 63                                                 NaN
# 65                                                 NaN
# 67                                       Trifid Nebula
# 68                                                 NaN
# 69                                                 NaN
# 70                                                 NaN
# 73                                                 NaN
# 75                                                 NaN
# 76                                                 NaN
# 80                                       Lagoon Nebula
# 81         Amas de l'Ecu de Sobieski,Wild Duck Cluster
# 82                                                 NaN
# 83                                                 NaN
# 84                                                 NaN
# 85                                                 NaN
# 87                                                 NaN
# 88                                                 NaN
# 91                                                 NaN
# 93                                                 NaN
# 94                                                 NaN
# 97                                          Owl Nebula
# 99                                                 NaN
# 100                                                NaN
# 102                                                NaN
# 104  Checkmark Nebula,Lobster Nebula,Swan Nebula,om...
# 105                                    Dumbbell Nebula
# 106                                                NaN
# 0                                             Pleiades
# 1                                                  NaN
#
#                                              NED_notes  \
# 2    The 2MASX position is centered on a superposed...
# 3                                                  NaN
# 4                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 21                                Four Galactic stars.
# 23                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 29                                                 NaN
# 31                                                 NaN
# 32                                                 NaN
# 33                                                 NaN
# 34                                                 NaN
# 35                                                 NaN
# 36                                                 NaN
# 37                                                 NaN
# 39                                                 NaN
# 40                                                 NaN
# 43                                                 NaN
# 44                    Position is for the Crab pulsar.
# 45                                                 NaN
# 46                                                 NaN
# ..                                                 ...
# 60                                                 NaN
# 63                                                 NaN
# 65                                                 NaN
# 67                                                 NaN
# 68                                                 NaN
# 69                                                 NaN
# 70    Included in the Milky Way starcloud MESSIER 024.
# 73                                                 NaN
# 75                                                 NaN
# 76                                                 NaN
# 80   Nominal position for NGC 6533 is -30 arcmin in...
# 81                                                 NaN
# 82                                                 NaN
# 83                                                 NaN
# 84   Likely associated with the Sagittarius Dwarf S...
# 85                                                 NaN
# 87                                                 NaN
# 88       Identification as NGC 6839 is very uncertain.
# 91                                                 NaN
# 93                                                 NaN
# 94                                                 NaN
# 97                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 102                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 0                                                  NaN
# 1                                                  NaN
#
#                                          OpenNGC_notes
# 2                                                  NaN
# 3                                V-mag taken from LEDA
# 4                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 14                                                 NaN
# 15                               V-mag taken from LEDA
# 16                               V-mag taken from LEDA
# 17                                                 NaN
# 18                               V-mag taken from LEDA
# 19                                                 NaN
# 21                               V-mag taken from LEDA
# 23            V-mag taken from HEASARC's messier table
# 26                                                 NaN
# 27                                                 NaN
# 29                                                 NaN
# 31                                                 NaN
# 32                               V-mag taken from LEDA
# 33                                                 NaN
# 34                                                 NaN
# 35                                                 NaN
# 36                                                 NaN
# 37                                                 NaN
# 39                                                 NaN
# 40                               V-mag taken from LEDA
# 43                                                 NaN
# 44                               V-mag taken from LEDA
# 45                                                 NaN
# 46                                                 NaN
# ..                                                 ...
# 60                                                 NaN
# 63                                                 NaN
# 65                                                 NaN
# 67   B-Mag taken from LEDA, V-mag taken from HEASAR...
# 68                                                 NaN
# 69                                                 NaN
# 70                                                 NaN
# 73                                                 NaN
# 75                                                 NaN
# 76                                                 NaN
# 80   B-Mag taken from LEDA, V-mag taken from HEASAR...
# 81                                                 NaN
# 82                                                 NaN
# 83                                                 NaN
# 84                               V-mag taken from LEDA
# 85                                                 NaN
# 87                                                 NaN
# 88                                                 NaN
# 91                                                 NaN
# 93                                                 NaN
# 94                                                 NaN
# 97                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 102                                                NaN
# 104  B-Mag taken from LEDA, V-mag taken from HEASAR...
# 105                                                NaN
# 106                              V-mag taken from LEDA
# 0    Coordinates taken from Simbad, VMag taken from...
# 1              VMag taken from HEASARC's messier table
#
# [70 rows x 37 columns]

# %% [markdown]
# ### 2.3. Le catalogue de Messier: *'jbcurtin_gitHub'*
# Ce catalogue ([Voir référence](https://github.com/jbcurtin/messier-catalogue)) est pricipalement intéressant pour les images qu'il contient pour chaque objet.

# %%
# Lecture de données depuis le fichier source vers un objet DataFrame
col_names = ['Messier_number_jbcurtin_gitHub',
    'NGC_IC_designation_jbcurtin_gitHub', 
    'Common_name_jbcurtin_gitHub',
    'image_jbcurtin_gitHub',
    'Object_type_jbcurtin_gitHub',
    'Distance_KLY_jbcurtin_gitHub',             
    'Constellation_jbcurtin_gitHub',
    'Apparent_magnitude_jbcurtin_gitHub',
    'Right_Ascension_jbcurtin_gitHub',        
    'Declinaison_jbcurtin_gitHub']
messier_with_picture_links_jbcurtin_gitHub = pd.read_csv(os.path.join(CHEMIN_SOURCES, "messier_with_picture_links_jbcurtin_gitHub.csv"), keep_default_na=True, sep=';', header=0, names=col_names)
messier_with_picture_links_jbcurtin_gitHub.loc[messier_with_picture_links_jbcurtin_gitHub['Common_name_jbcurtin_gitHub']==' ',
                       'Common_name_jbcurtin_gitHub'] = np.nan #not a space
    
messier_with_picture_links_jbcurtin_gitHub.dtypes
# Out:
# Messier_number_jbcurtin_gitHub         object
# NGC_IC_designation_jbcurtin_gitHub     object
# Common_name_jbcurtin_gitHub            object
# image_jbcurtin_gitHub                  object
# Object_type_jbcurtin_gitHub            object
# Distance_KLY_jbcurtin_gitHub           object
# Constellation_jbcurtin_gitHub          object
# Apparent_magnitude_jbcurtin_gitHub    float64
# Right_Ascension_jbcurtin_gitHub        object
# Declinaison_jbcurtin_gitHub            object
# dtype: object

# %%
# Merge entre 'messier_catalogue' et le nouveau dataset
messier_catalogue2 = messier_with_picture_links_jbcurtin_gitHub.merge(messier_catalogue,how='left', left_on='Messier_number_jbcurtin_gitHub', right_on='Messier_number')
messier_catalogue2.shape
# Out:
# (110, 47)

# %%
#keep 'Common_name_jbcurtin_gitHub', delete_Common_names
messier_catalogue2.loc[messier_catalogue2['Common_name_jbcurtin_gitHub'].isna(),
                   'Common_name_jbcurtin_gitHub'] = messier_catalogue2['Common_names']

# In 'Object_type_jbcurtin_gitHub', Galaxy is subtyped. So we should keep that info
# Keep 'object_type', delete 'Object_type_jbcurtin_gitHub'
messier_catalogue2.loc[messier_catalogue2['object_type'].str.contains('Galaxy'),
                   'object_type'] = messier_catalogue2['Object_type_jbcurtin_gitHub']

#Delete 'Constellation_jbcurtin_gitHub'
messier_catalogue2.loc[messier_catalogue2['Constellation_Latin'].isna(),
                   'Constellation_Latin'] = messier_catalogue2['Constellation_jbcurtin_gitHub']

drop_list = ['Common_names', 'Messier_number_jbcurtin_gitHub', 'NGC_IC_designation_jbcurtin_gitHub', 
             'Object_type_jbcurtin_gitHub', 'Distance_KLY_jbcurtin_gitHub', 'Constellation_jbcurtin_gitHub',
            'Right_Ascension_jbcurtin_gitHub', 'Declinaison_jbcurtin_gitHub']
rename_lis = {'Common_name_jbcurtin_gitHub': 'Common_name'}

messier_catalogue2 = messier_catalogue2.drop(columns=drop_list)
messier_catalogue2 = messier_catalogue2.rename(columns=rename_lis)
messier_catalogue2.shape
# Out:
# (110, 39)

# %% [markdown]
# ### 2.4. Le catalogue de Messier: *'Nexstarsite'*
#
# https://www.nexstarsite.com/Book/DSO.htm

# %%
MessierObjects_nexstarsite = pd.read_excel(os.path.join(CHEMIN_SOURCES, "nexstarsite", "MessierObjects_nexstarsite.xls"), skiprows=2)
MessierObjects_nexstarsite.dtypes
# Out:
# ObjectNum          int64
# Name              object
# Type              object
# Constellation     object
# RAHour             int64
# RAMinute         float64
# DecSign           object
# DecDeg             int64
# DecMinute        float64
# Magnitude         object
# Info              object
# Distance (ly)      int64
# dtype: object

# %% [markdown]
# Ce dataset ne contient pas de nouvelles données.

# %%
messier_catalogue_final = messier_catalogue2

# %%
messier_catalogue_final.dtypes
# Out:
# Common_name                            object
# image_jbcurtin_gitHub                  object
# Apparent_magnitude_jbcurtin_gitHub    float64
# Messier_number                         object
# NGC_IC_designation                     object
# object_type                            object
# Season                                 object
# Magnitude                               int64
# Constellation_EN                       object
# Constellation_FR                       object
# Constellation_Latin                    object
# Distance_light_year                   float64
# Size                                   object
# Discoverer                             object
# Year                                  float64
# Image1                                 object
# Image2                                 object
# Constelation_abr                       object
# Right_Ascension                        object
# Declinaison                            object
# Constelation_name_abrv                 object
# major_axis                            float64
# minor_axis                            float64
# major__axis_position_angle            float64
# B_Apparent_Magnitude                  float64
# V_Apparent_Magnitude                  float64
# J_Apparent_Magnitude                  float64
# H_Apparent_Magnitude                  float64
# K_Apparent_Magnitude                  float64
# Mean_surface_brigthness               float64
# Hubble_morphological_type              object
# center_star_U_maghitude               float64
# center_star_B_maghitude               float64
# center_star_V_maghitude               float64
# NGC_numner                             object
# Center_star_name                       object
# Identifiers                            object
# NED_notes                              object
# OpenNGC_notes                          object
# dtype: object

# %% [markdown]
# ## 3. Construction du catalogue de Caldwell

# %%
CaldwellObjects_nexstarsite = pd.read_excel(os.path.join(CHEMIN_SOURCES, "nexstarsite", "CaldwellObjects_nexstarsite.xls"), skiprows=2)
CaldwellObjects_nexstarsite.shape
# Out:
# (109, 11)

# %%
CaldwellObjects_nexstarsite.dtypes
# Out:
# ObjectNum          int64
# Name              object
# Type              object
# Constellation     object
# Magnitude         object
# Info              object
# RAHour             int64
# RAMinute         float64
# DecSign           object
# DecDeg             int64
# DecMinute          int64
# dtype: object

# %%
NGC_mattiaAverga_GitHub.dtypes
# Out:
# NGC_IC_designation             object
# object_type                    object
# Right_Ascension                object
# Declinaison                    object
# Constelation_name_abrv         object
# major_axis                    float64
# minor_axis                    float64
# major__axis_position_angle    float64
# B_Apparent_Magnitude          float64
# V_Apparent_Magnitude          float64
# J_Apparent_Magnitude          float64
# H_Apparent_Magnitude          float64
# K_Apparent_Magnitude          float64
# Mean_surface_brigthness       float64
# Hubble_morphological_type      object
# center_star_U_maghitude       float64
# center_star_B_maghitude       float64
# center_star_V_maghitude       float64
# Messier_number                float64
# NGC_numner                     object
# IC_number                      object
# Center_star_name               object
# Identifiers                    object
# Common_names                   object
# NED_notes                      object
# OpenNGC_notes                  object
# dtype: object

# %% [markdown]
# ## 4. Construction du catalogue de Herschel400

# %%
Herschel400_nexstarsite = pd.read_excel(os.path.join(CHEMIN_SOURCES, "nexstarsite","Herschel400_nexstarsite.xls"), skiprows=2)
Herschel400_nexstarsite.shape
# Out:
# (400, 11)

# %% [markdown]
# # Catalogues Merging

# %% [markdown]
# ## Final Catalogue file

# %%
reorder = ['Messier_number', 'NGC_IC_designation', 'object_type', 'Common_name', 'Constellation_FR', 'Constellation_EN',
'Constellation_Latin', 'Constelation_abr','Constelation_name_abrv','Hubble_morphological_type', 'Discoverer', 'Year', 
'Season', 'Right_Ascension','Declinaison', 'Distance_light_year', 'Size', 'major_axis', 'minor_axis', 'major__axis_position_angle',
'Apparent_magnitude_jbcurtin_gitHub', 'Magnitude', 'B_Apparent_Magnitude', 'V_Apparent_Magnitude', 'J_Apparent_Magnitude',
'H_Apparent_Magnitude', 'K_Apparent_Magnitude', 'Mean_surface_brigthness',
'Center_star_name', 'center_star_U_maghitude', 'center_star_B_maghitude', 'center_star_V_maghitude',
'Image1', 'Image2', 'image_jbcurtin_gitHub', 'NGC_numner', 'Identifiers', 'NED_notes', 'OpenNGC_notes']

messier_catalogue_final = messier_catalogue_final[reorder]

# %%
#messier_catalogue_final.to_csv(os.path.join(CHEMIN_OUTPUT, "Final_catalogue.csv"),";")
messier_catalogue_final.to_csv("Final_catalogue.csv",";")
